# %%
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline  
import pandas as pd

import os
from math import log, exp

from lab3.generator import \
    gauss, gauss_distribution, \
    lognormal, lognormal_distribution, lognormal_prob, lognormal

from lab2.utils import run

# %%
sigma = 1
plt.figure(figsize=(20,10))
m = 1
generated_values = list(lognormal(m, sigma, 1000))
info = plt.hist(generated_values, bins = 100, color= 'black', alpha = 0.5,  density=True)

m  = 0.7
generated_values = list(lognormal(m, sigma, 1000))
info = plt.hist(generated_values, bins = 100, color= 'green', alpha = 0.5,  density=True)

m  = 0.5
generated_values = list(lognormal(m, sigma, 1000))
info = plt.hist(generated_values, bins = 100, color= 'pink', alpha = 0.5,  density=True)

m  = 0.2
generated_values = list(lognormal(m, sigma, 1000))
info = plt.hist(generated_values, bins = 100, color= 'red', alpha = 0.5,  density=True)

m = 0.4
generated_values = list(lognormal(m, sigma, 1000))
#info = plt.hist(generated_values, bins = 50, color= 'orange', alpha = 0.5,  density=True)

# %%
m = 0.4

sigma = 1
plt.figure(figsize=(20,10))
generated_values = list(lognormal(m, sigma, 1000))
info = plt.hist(generated_values, bins = 100, color= 'black', alpha = 0.5,  density=True)

sigma = 1
generated_values = list(lognormal(m, sigma, 1000))
info = plt.hist(generated_values, bins = 100, color= 'red', alpha = 0.5,  density=True)


sigma = 1/4
generated_values = list(lognormal(m, sigma, 1000))
info = plt.hist(generated_values, bins = 100, color= 'pink', alpha = 0.5,  density=True)

sigma = 1/8
generated_values = list(lognormal(m, sigma, 1000))
info = plt.hist(generated_values, bins = 100, color= 'orange', alpha = 0.5,  density=True)

# %%
hist_bins = plt.hist(generated_values, bins = 100, color = 'pink', normed=  True)

hist = hist_bins[0]
bins = hist_bins[1]
hist_theory = [lognormal_prob(m,sigma,x)  for x in bins]

plt.plot(hist_theory)
# Out:
# C:\Users\PC\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %% [markdown]
# ### Плотность вероятности

# %%
X = np.linspace(0.01,5,1000) #  linearly spaced numbers

sigma = 1
mu = 1
theory_disribution = [lognormal_prob(mu,sigma,x) for x in X]
plt.plot(X, theory_disribution, color = 'black')


mu = 0.2
theory_disribution = [lognormal_prob(mu,sigma,x) for x in X]
plt.plot(X, theory_disribution, color = 'blue')


m = 0.5
mu = 0.5
theory_disribution = [lognormal_prob(mu,sigma,x) for x in X]
plt.plot(X, theory_disribution, color = 'orange')

m = 0.7
mu = 0.7
theory_disribution = [lognormal_prob(mu,sigma,x) for x in X]
plt.plot(X, theory_disribution, color = 'yellow')

mu = 0
theory_disribution = [lognormal_prob(mu,sigma,x) for x in X]
plt.plot(X, theory_disribution, color = 'red')

# %%
sigma = 1
plt.figure(figsize=(20,10))
m = 1
generated_values = list(lognormal(m, sigma, 1000))
info = plt.hist(generated_values, bins = 100, color= 'black', alpha = 0.5,  density=True)

m  = 0.7
generated_values = list(lognormal(m, sigma, 1000))
info = plt.hist(generated_values, bins = 100, color= 'green', alpha = 0.5,  density=True)

m  = 0.5
generated_values = list(lognormal(m, sigma, 1000))
info = plt.hist(generated_values, bins = 100, color= 'pink', alpha = 0.5,  density=True)

m  = 0.2
generated_values = list(lognormal(m, sigma, 1000))
info = plt.hist(generated_values, bins = 100, color= 'red', alpha = 0.5,  density=True)

m = 0.4
generated_values = list(lognormal(m, sigma, 1000))
#info = plt.hist(generated_values, bins = 50, color= 'orange', alpha = 0.5,  density=True)

# %%
mu = 0
X = np.linspace(0.01,3,1000) #  linearly spaced numbers
sigma =10
theory_disribution = [lognormal_prob(mu,sigma,x) for x in X]
plt.plot(X, theory_disribution, color = 'black')

sigma =3/2
theory_disribution = [lognormal_prob(mu,sigma,x) for x in X]
plt.plot(X, theory_disribution, color = 'blue')


sigma = 1
theory_disribution = [lognormal_prob(mu,sigma,x) for x in X]
plt.plot(X, theory_disribution, color = 'orange')

sigma = 1/2
theory_disribution = [lognormal_prob(mu,sigma,x) for x in X]
plt.plot(X, theory_disribution, color = 'yellow')

sigma = 1/4
theory_disribution = [lognormal_prob(mu,sigma,x) for x in X]
plt.plot(X, theory_disribution, color = 'red')

# %% [markdown]
# ### Функция распределения

# %%
m = 0.2

mu = log(m)
X = np.linspace(0.0001,1,1000) #  linearly spaced numbers

sigma =7
theory_disribution = [lognormal_distribution(mu,sigma,x) for x in X]
plt.plot(X, theory_disribution, color = 'b')

sigma = 3/2
theory_disribution = [lognormal_distribution(mu,sigma,x) for x in X]
plt.plot(X, theory_disribution, color = 'r')

sigma = 1
theory_disribution = [lognormal_distribution(mu,sigma,x) for x in X]
plt.plot(X, theory_disribution, color = 'green')

sigma = 1/2
theory_disribution = [lognormal_distribution(mu,sigma,x) for x in X]
plt.plot(X, theory_disribution, color = 'yellow')

sigma = 1/6
theory_disribution = [lognormal_distribution(mu,sigma,x) for x in X]
plt.plot(X, theory_disribution, color = 'pink')
